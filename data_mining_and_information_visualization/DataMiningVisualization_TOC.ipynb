# %% [markdown]
# # **データマイニングと情報可視化 / Data mining and information visualization**
#
# ## 稲垣紫緒 / Shio INAGAKI
# 理学研究院　物理学部門 / 共創学部(エリア横断)<br>
# E-mail: inagaki@phys.kyushu-u.ac.jp<br>
# 居室：ウェスト1号館 W1-A823号室<br>
# <br>
# School of Science, Dept. of Physics / School of Interdisciplinary Science and Innovation<br>
# E-mail: inagaki@phys.kyushu-u.ac.jp<br>
# Office: Room W1-A823, West 1 building

# %% [markdown]
# # 準備 / Preparation
# これから、毎回授業の講義ノートと、演習問題、課題をファイルで配布します。このファイル(DataMiningVisualization.ipynb) がその目次になります。<br>
# 今後配布する資料を、以下のような構成のディレクトリを作って、保存してください。<br>
# <br>
# I will distribute lecture notes, exercises, and reports every week. This file (DataMiningVisualization.ipynb) is the table of contents linked to those files.<br>
# Please make a directory for this course and save files in the directory.<br>
# <br>
# > /Desktop/DataMiningVisualization/ : save lecture notes (*.pdf), exercises  (*.ipynb) and reports (*.ipynb)<br>
# > /Desktop/DataMiningVisualization/image/ : save the image files (*.jpg. *.png) <br>
# > /Desktop/DataMiningVisualization/data/ : save data files (*.txt, *.csv, *.xlsx)<br>
#
# <img src="img/w0_Folders.png" width=80%>

# %% [markdown]
# ## Table of Contents
# ***
#
# * **Week 0: Preparation**<br>
# <font size="4">**Jupyter Notebookの基本**</font><br>
#     * [事前学習/ Preparation](Ex_Week0.ipynb): Jupyter Notebook の基礎をちょっとまとめました。/ Preparation material for Jupyter Notebook.
#
# ***
# * **Week 1**<br>
# <font size="4">**概要と動作環境の確認(PythonとJupyter)**</font><br>
# <font size="4">**Outline of the course and check the PC environment**</font><br>
#     * [演習 / Exercise](Ex_Week1.ipynb)
#     * [レポート / Assignment](Rep_Week1.ipynb)
#     * [Pandas演習 / Exercise for Pandas](Ex_Week0_Pandas.ipynb): Pandasの基礎をまとめました。提出不要です。Pandasに詳しくない人は、これで練習するとよいでしょう。/ Basics of Pandas. No need to submit. Please use this exercise if you are not familiar with Pandas.
#
# ***
#
# * **Week 2**<br>
# <font size="4">**データマイニング手法1-1：マーケットバスケット分析（講義と分析手法の基礎）**</font><br>
# <font size="4">**Method 1-1: Market basket analysis (Lecture and basic skills)**</font><br>
#     * [演習 / Exercise](Ex_Week2.ipynb)
#     * [レポート / Assignment](Rep_Week2.ipynb)
#
# ***
# * **Week 3**<br>
# <font size="4">**データマイニング手法1-2：マーケットバスケット分析（データ解析と可視化）**</font><br>
# <font size="4">**Method 1-2: Market basket analysis (Analyze data &amp; visualization)**</font><br>
#     * [演習 / Exercise](Ex_Week3.ipynb)
#     * [レポート / Assignment](Rep_Week3.ipynb)
#
# ***
#
# * **Week 4**<br>
# <font size="4">**データマイニング手法2-1：クラスター分析（講義と分析手法の基礎）**</font><br>
# <font size="4">**Method 2-1: Clustering analysis (Lecture and basic skills)**</font><br>
#     * [演習 / Exercise](Ex_Week4.ipynb)
#     * [レポート / Assignment](Rep_Week4.ipynb)
#
# ***
# * **Week 5**<br>
# <font size="4">**データマイニング手法2-2：クラスター分析（データ解析と可視化）**</font><br>
# <font size="4">**Method 2-2: Clustering analysis (Analyze data &amp; visualization)**</font><br>
#     * [演習 / Exercise](Ex_Week5.ipynb)
#     * [レポート / Assignment](Rep_Week5.ipynb)
#
# ***
# * **Week 6**<br>
# <font size="4">**データマイニング手法3-1：回帰分析（講義と分析手法の基礎）**</font><br>
# <font size="4">**Method 3-1: Regression (Lecture and basic skills)**</font><br>
#     * [演習 / Exercise](Ex_Week6.ipynb)
#     * [レポート / Assignment](Rep_Week6.ipynb)
#
# ***
# * **Week 7**<br>
# <font size="4">**データマイニング手法3-2：回帰分析（データ解析と可視化）**</font><br>
# <font size="4">**Method 3-2: Regression (Analyze data &amp; visualization)**</font><br>
#     * [演習 / Exercise](Ex_Week7.ipynb)
#     * [レポート / Assignment](Rep_Week7.ipynb)
#
# ***
# * **Week 8**<br>
# <font size="4">**応用・まとめ**</font><br>
# <font size="4">**Applications**</font><br>
#     * [演習 / Exercise](Ex_Week8.ipynb)

# %% [markdown]
# # 参考図書
# 〇マークがついているものは九大図書館の蔵書にあります。<br>
# いい本があったら、紹介してください!!<br>
# <br>
# I am sorry for listing most of the references written in Japanese.<br>
# Let me introduce you only a couple of helpful websites on Python.<br>
# Please tell me if you know any helpful websites on Python, Data mining, or visualization.
# * [Python 3 Documentation](https://docs.python.org/)
# * [Python Tutorial](https://www.w3schools.com/python/)
# * [10 Minutes to pandas @ Pandas documentation](https://pandas.pydata.org/pandas-docs/stable/getting_started/10min.html)
#
# Recommended books on Data Science
# * [Super Crunchers](https://www.amazon.co.jp/Super-Crunchers-Ian-Ayres/dp/0719564654) written by Ian Ayres.
# * [Factfulness: Ten Reasons We're Wrong About The World - And Why Things Are Better Than You Think](https://www.amazon.com/Factfulness-Reasons-World-Things-Better/dp/1250107814/)
# written by Hans Rosling.
#
# ## Pythonとデータマイニング
# + 〇[Pythonによるデータマイニングと機械学習](https://www.amazon.co.jp/Python%E3%81%AB%E3%82%88%E3%82%8B%E3%83%87%E3%83%BC%E3%82%BF%E3%83%9E%E3%82%A4%E3%83%8B%E3%83%B3%E3%82%B0%E3%81%A8%E6%A9%9F%E6%A2%B0%E5%AD%A6%E7%BF%92-%E8%97%A4%E9%87%8E-%E5%B7%96/dp/4274224120/ref=sr_1_1?__mk_ja_JP=%E3%82%AB%E3%82%BF%E3%82%AB%E3%83%8A&keywords=Python%E3%81%AB%E3%82%88%E3%82%8B%E3%83%87%E3%83%BC%E3%82%BF%E3%83%9E%E3%82%A4%E3%83%8B%E3%83%B3%E3%82%B0%E3%81%A8%E6%A9%9F%E6%A2%B0%E5%AD%A6%E7%BF%92&qid=1569984252&sr=8-1)
#     + 著者：藤野 巖
#     + ISBN: 978-4274224126
#     + サンプルプログラムがDLできる。説明も丁寧で分かりやすい。内容も豊富。初級者向け。
# + 〇[東京大学のデータサイエンティスト育成講座 　Pythonで手を動かして学ぶデ―タ分析](https://www.amazon.co.jp/%E6%9D%B1%E4%BA%AC%E5%A4%A7%E5%AD%A6%E3%81%AE%E3%83%87%E3%83%BC%E3%82%BF%E3%82%B5%E3%82%A4%E3%82%A8%E3%83%B3%E3%83%86%E3%82%A3%E3%82%B9%E3%83%88%E8%82%B2%E6%88%90%E8%AC%9B%E5%BA%A7-Python%E3%81%A7%E6%89%8B%E3%82%92%E5%8B%95%E3%81%8B%E3%81%97%E3%81%A6%E5%AD%A6%E3%81%B6%E3%83%87%E2%80%95%E3%82%BF%E5%88%86%E6%9E%90-%E5%A1%9A%E6%9C%AC%E9%82%A6%E5%B0%8A/dp/4839965250/ref=pd_sim_14_4/355-5686127-1635768?_encoding=UTF8&pd_rd_i=4839965250&pd_rd_r=c00b05f4-d233-4c4d-bb7f-173d98806ed0&pd_rd_w=ZI8zK&pd_rd_wg=5JsQ6&pf_rd_p=2e61d088-fdb1-443a-804b-afc322ee8b23&pf_rd_r=KDNCJQAQ9888JA7EZG8C&psc=1&refRID=KDNCJQAQ9888JA7EZG8C)
#     + 塚本邦尊, 山田典一, 大澤文孝
#     + ISBN: 978-4839965259
#     + サンプルプログラムがDLできる。例題が豊富。手を動かすのによい。説明は少なめで、自分で調べて補う必要がある。中級者向け。
# + 〇[やさしい確率・情報・データマイニング](https://www.amazon.co.jp/%E3%82%84%E3%81%95%E3%81%97%E3%81%84%E7%A2%BA%E7%8E%87%E3%83%BB%E6%83%85%E5%A0%B1%E3%83%BB%E3%83%87%E3%83%BC%E3%82%BF%E3%83%9E%E3%82%A4%E3%83%8B%E3%83%B3%E3%82%B0-%E7%AC%AC2%E7%89%88-%E6%9C%88%E6%9C%AC-%E6%B4%8B/dp/4627095627/ref=sr_1_1?__mk_ja_JP=%E3%82%AB%E3%82%BF%E3%82%AB%E3%83%8A&keywords=%E3%82%84%E3%81%95%E3%81%97%E3%81%84%E7%A2%BA%E7%8E%87%E3%83%BB%E6%83%85%E5%A0%B1%E3%83%BB%E3%83%87%E3%83%BC%E3%82%BF%E3%83%9E%E3%82%A4%E3%83%8B%E3%83%B3%E3%82%B0&qid=1569984223&sr=8-1)
#     + 著者：月本洋, 松本一教
#     + ISBN: 978-4627095625
#     + 初心者向け。説明は丁寧。サンプルプログラムはない。
# + 〇[データサイエンス教本 Pythonで学ぶ統計分析・パターン認識・深層学習・信号処理・時系列データ分析](https://www.amazon.co.jp/%E3%83%87%E3%83%BC%E3%82%BF%E3%82%B5%E3%82%A4%E3%82%A8%E3%83%B3%E3%82%B9%E6%95%99%E6%9C%AC-Python%E3%81%A7%E5%AD%A6%E3%81%B6%E7%B5%B1%E8%A8%88%E5%88%86%E6%9E%90%E3%83%BB%E3%83%91%E3%82%BF%E3%83%BC%E3%83%B3%E8%AA%8D%E8%AD%98%E3%83%BB%E6%B7%B1%E5%B1%A4%E5%AD%A6%E7%BF%92%E3%83%BB%E4%BF%A1%E5%8F%B7%E5%87%A6%E7%90%86%E3%83%BB%E6%99%82%E7%B3%BB%E5%88%97%E3%83%87%E3%83%BC%E3%82%BF%E5%88%86%E6%9E%90-%E6%A9%8B%E6%9C%AC-%E6%B4%8B%E5%BF%97/dp/427422290X/ref=sr_1_1?__mk_ja_JP=%E3%82%AB%E3%82%BF%E3%82%AB%E3%83%8A&keywords=%E3%83%87%E3%83%BC%E3%82%BF%E3%82%B5%E3%82%A4%E3%82%A8%E3%83%B3%E3%82%B9%E6%95%99%E6%9C%AC&qid=1569983930&s=books&sr=1-1)
#     + 著者：橋本 洋志、牧野 浩二
#     + ISBN: 978-4274222900
#
# ## Python, Numpy, Pandas, Matplotlib など、解析ツールの使い方がメイン
# + [Pythonによるあたらしいデータ分析の教科書](https://www.amazon.co.jp/Python%E3%81%AB%E3%82%88%E3%82%8B%E3%81%82%E3%81%9F%E3%82%89%E3%81%97%E3%81%84%E3%83%87%E3%83%BC%E3%82%BF%E5%88%86%E6%9E%90%E3%81%AE%E6%95%99%E7%A7%91%E6%9B%B8-AI-TECHNOLOGY-%E5%AF%BA%E7%94%B0-%E5%AD%A6/dp/4798158348/ref=sr_1_1?__mk_ja_JP=%E3%82%AB%E3%82%BF%E3%82%AB%E3%83%8A&keywords=Python%E3%81%AB%E3%82%88%E3%82%8B%E3%81%82%E3%81%9F%E3%82%89%E3%81%97%E3%81%84%E3%83%87%E3%83%BC%E3%82%BF%E5%88%86%E6%9E%90%E3%81%AE%E6%95%99%E7%A7%91%E6%9B%B8&qid=1569984184&sr=8-1)
#     + 著者：寺田 学, 辻 真吾, 鈴木 たかの, 福島 真太朗
#     + ISBN:978-4798158341
#     + 初心者向け。初歩の初歩。ほぼPython。データ分析の手法の詳細は少ない。
# + [pandasライブラリ活用入門 ](https://www.amazon.co.jp/Python%E3%83%87%E3%83%BC%E3%82%BF%E5%88%86%E6%9E%90-%E6%A9%9F%E6%A2%B0%E5%AD%A6%E7%BF%92%E3%81%AE%E3%81%9F%E3%82%81%E3%81%AE%E5%9F%BA%E6%9C%AC%E3%82%B3%E3%83%BC%E3%83%87%E3%82%A3%E3%83%B3%E3%82%B0-pandas%E3%83%A9%E3%82%A4%E3%83%96%E3%83%A9%E3%83%AA%E6%B4%BB%E7%94%A8%E5%85%A5%E9%96%80-impress-gear/dp/4295005657/ref=sr_1_1?__mk_ja_JP=%E3%82%AB%E3%82%BF%E3%82%AB%E3%83%8A&keywords=Pandas%E3%83%A9%E3%82%A4%E3%83%96%E3%83%A9%E3%83%AA&qid=1575094835&sr=8-1)
#     +  Daniel Y. Chen (著), 福島 真太朗 (監修), 吉川邦夫 (翻訳)
#     + ISBN:978-4295005650
#     + Pandasの使い方。Pandasは授業でよく使う予定です。一通り基礎を学ぶと授業内容が分かりやすいはず。
# + 〇[Pythonによるデータ分析入門 第2版 ―NumPy、pandasを使ったデータ処理](https://www.amazon.co.jp/Python%E3%81%AB%E3%82%88%E3%82%8B%E3%83%87%E3%83%BC%E3%82%BF%E5%88%86%E6%9E%90%E5%85%A5%E9%96%80-%E7%AC%AC2%E7%89%88-%E2%80%95NumPy%E3%80%81pandas%E3%82%92%E4%BD%BF%E3%81%A3%E3%81%9F%E3%83%87%E3%83%BC%E3%82%BF%E5%87%A6%E7%90%86-Wes-McKinney/dp/487311845X/ref=sr_1_1?__mk_ja_JP=%E3%82%AB%E3%82%BF%E3%82%AB%E3%83%8A&keywords=Python%E3%81%AB%E3%82%88%E3%82%8B%E3%83%87%E3%83%BC%E3%82%BF%E5%88%86%E6%9E%90%E5%85%A5%E9%96%80&qid=1569984471&sr=8-1)
#     + 著者：Wes McKinney; 瀬戸山 雅人, 小林 儀匡, 滝口 開資(翻訳)
#     + ISBN: 978-4873118451
#     + 有名なオライリーシリーズ。分析手法の紹介はないけど、Numpy, Pandas, Matplotlibなど、ライブラリの使い方など技術的な内容が中心。中級者向け。
# + 〇[Pythonデータサイエンスハンドブック ―Jupyter、NumPy、pandas、Matplotlib、scikit-learnを使ったデータ分析、機械学習](https://www.amazon.co.jp/Python%E3%83%87%E3%83%BC%E3%82%BF%E3%82%B5%E3%82%A4%E3%82%A8%E3%83%B3%E3%82%B9%E3%83%8F%E3%83%B3%E3%83%89%E3%83%96%E3%83%83%E3%82%AF-%E2%80%95Jupyter%E3%80%81NumPy%E3%80%81pandas%E3%80%81Matplotlib%E3%80%81scikit-learn%E3%82%92%E4%BD%BF%E3%81%A3%E3%81%9F%E3%83%87%E3%83%BC%E3%82%BF%E5%88%86%E6%9E%90%E3%80%81%E6%A9%9F%E6%A2%B0%E5%AD%A6%E7%BF%92-Jake-VanderPlas/dp/4873118417/ref=pd_sim_14_1/355-5686127-1635768?_encoding=UTF8&pd_rd_i=4873118417&pd_rd_r=006bc256-1783-44b4-b4ad-5747c1adaa90&pd_rd_w=JMKdS&pd_rd_wg=IgOyO&pf_rd_p=2e61d088-fdb1-443a-804b-afc322ee8b23&pf_rd_r=8KP0Y6BVMABHBKT1CCGD&psc=1&refRID=8KP0Y6BVMABHBKT1CCGD)
#     + 著者：Jake VanderPlas; 菊池 彰 (翻訳)
#     + ISBN: 978-4873118413
#     + 有名なオライリーシリーズ。分析手法の紹介はないけど、Numpy, Pandas, Matplotlibなど、ライブラリの使い方など技術的な内容が中心。中級者向け。
#
# ## 読み物
# + 〇[その数学が戦略を決める](https://www.amazon.co.jp/%E3%81%9D%E3%81%AE%E6%95%B0%E5%AD%A6%E3%81%8C%E6%88%A6%E7%95%A5%E3%82%92%E6%B1%BA%E3%82%81%E3%82%8B-%E6%96%87%E6%98%A5%E6%96%87%E5%BA%AB-%E3%82%A4%E3%82%A2%E3%83%B3-%E3%82%A8%E3%82%A2%E3%83%BC%E3%82%BA/dp/416765170X/ref=pd_sbs_14_t_0/355-5686127-1635768?_encoding=UTF8&pd_rd_i=416765170X&pd_rd_r=9f9186c4-0eba-46fd-a3cc-a8f1e6adc452&pd_rd_w=6PwMB&pd_rd_wg=zwoM4&pf_rd_p=ca22fd73-0f1e-4b39-9917-c84a20b3f3a8&pf_rd_r=CJZ3EV20H40KTPT5697D&psc=1&refRID=CJZ3EV20H40KTPT5697D)
#     + 著者： Ian Ayres ; 山形 浩生  (翻訳)
#     + ISBN: 978-4167651701
#     + 主に回帰分析を用いて近い将来を予測し、どのようにビジネス判断をしていくか、豊富な事例を挙げて説明しています。みんなに読んでほしい一冊。
#     + 原著はこちら。[Super Crunchers](https://www.amazon.co.jp/Super-Crunchers-Ian-Ayres/dp/0719564654)
# + [FACTFULNESS(ファクトフルネス) 10の思い込みを乗り越え、データを基に世界を正しく見る習慣](https://www.amazon.co.jp/gp/product/4822289605/ref=ppx_yo_dt_b_search_asin_title?ie=UTF8&psc=1)
#     + 著者： ハンス・ロスリング, オーラ・ロスリング, アンナ・ロスリング・ロンランド; 関 美和, 上杉 周作 (翻訳)
#     + ISBN: 978-4822289607
#     + データを正しく読み取るとは??みんなに読んでほしい一冊。図書館にないのが残念。[TED talk](https://www.ted.com/talks/hans_rosling_shows_the_best_stats_you_ve_ever_seen?)もどうぞ。
#     + 原著はこちら。[Factfulness: Ten Reasons We're Wrong About the World--and Why Things Are Better Than You Think](https://www.amazon.com/Factfulness-Reasons-World-Things-Better/dp/1250107814/)
# + 〇[数式を使わないデータマイニング入門 隠れた法則を発見する](https://www.amazon.co.jp/%E6%95%B0%E5%BC%8F%E3%82%92%E4%BD%BF%E3%82%8F%E3%81%AA%E3%81%84%E3%83%87%E3%83%BC%E3%82%BF%E3%83%9E%E3%82%A4%E3%83%8B%E3%83%B3%E3%82%B0%E5%85%A5%E9%96%80-%E9%9A%A0%E3%82%8C%E3%81%9F%E6%B3%95%E5%89%87%E3%82%92%E7%99%BA%E8%A6%8B%E3%81%99%E3%82%8B-%E5%85%89%E6%96%87%E7%A4%BE%E6%96%B0%E6%9B%B8-%E5%B2%A1%E5%B6%8B-%E8%A3%95%E5%8F%B2/dp/4334033555/ref=sr_1_1?__mk_ja_JP=%E3%82%AB%E3%82%BF%E3%82%AB%E3%83%8A&crid=1E8FS2EHRPHJ8&keywords=%E6%95%B0%E5%BC%8F%E3%82%92%E4%BD%BF%E3%82%8F%E3%81%AA%E3%81%84%E3%83%87%E3%83%BC%E3%82%BF%E3%83%9E%E3%82%A4%E3%83%8B%E3%83%B3%E3%82%B0&qid=1570002334&sprefix=%E6%95%B0%E5%BC%8F%E3%82%92%E4%BD%BF%E3%82%8F%E3%81%AA%E3%81%84%2Caps%2C231&sr=8-1)
#     + 著者：岡嶋 裕史
#     + ISBN: 978-4334033552
#     + 初心者向け。式がないので、イメージはつかみやすい。読み物。例がシンプルすぎて、理系には物足りないかも。。。
# + 〇[最新データサイエンスがよ~くわかる本 : 基礎からビジネスへの応用までを俯瞰](https://www.amazon.co.jp/%E5%9B%B3%E8%A7%A3%E5%85%A5%E9%96%80-%E3%83%87%E3%83%BC%E3%82%BF%E3%82%B5%E3%82%A4%E3%82%A8%E3%83%B3%E3%82%B9%E3%81%8C%E3%82%88%EF%BD%9E%E3%81%8F%E3%82%8F%E3%81%8B%E3%82%8B%E6%9C%AC-How-nual%E5%9B%B3%E8%A7%A3%E5%85%A5%E9%96%80Visual-Guide-Book/dp/4798055875/ref=sr_1_1?__mk_ja_JP=%E3%82%AB%E3%82%BF%E3%82%AB%E3%83%8A&keywords=%E6%9C%80%E6%96%B0%E3%83%87%E3%83%BC%E3%82%BF%E3%82%B5%E3%82%A4%E3%82%A8%E3%83%B3%E3%82%B9%E3%81%8C%E3%82%88%E3%80%9C%E3%81%8F%E3%82%8F%E3%81%8B%E3%82%8B%E6%9C%AC&qid=1569984127&sr=8-1)
#     + 著者：高木章光, 鈴木英太
#     + ISBN: 978-4798055879
#     + 初心者向け。ざっくり書いてある。自分で出来るようにはならないが、イメージはつかみやすい。読み物。
# + 〇[ビッグデータを活かすデータサイエンス -クロス集計から機械学習までのビジネス活用事例-](https://www.amazon.co.jp/%E3%83%93%E3%83%83%E3%82%B0%E3%83%87%E3%83%BC%E3%82%BF%E3%82%92%E6%B4%BB%E3%81%8B%E3%81%99%E3%83%87%E3%83%BC%E3%82%BF%E3%82%B5%E3%82%A4%E3%82%A8%E3%83%B3%E3%82%B9-%E3%82%AF%E3%83%AD%E3%82%B9%E9%9B%86%E8%A8%88%E3%81%8B%E3%82%89%E6%A9%9F%E6%A2%B0%E5%AD%A6%E7%BF%92%E3%81%BE%E3%81%A7%E3%81%AE%E3%83%93%E3%82%B8%E3%83%8D%E3%82%B9%E6%B4%BB%E7%94%A8%E4%BA%8B%E4%BE%8B-%E9%85%92%E5%B7%BB%E9%9A%86%E6%B2%BB/dp/4489022018/ref=sr_1_1?__mk_ja_JP=%E3%82%AB%E3%82%BF%E3%82%AB%E3%83%8A&keywords=%E3%83%93%E3%83%83%E3%82%B0%E3%83%87%E3%83%BC%E3%82%BF%E3%82%92%E6%B4%BB%E3%81%8B%E3%81%99%E3%83%87%E3%83%BC%E3%82%BF%E3%82%B5%E3%82%A4%E3%82%A8%E3%83%B3%E3%82%B9+%3A+%E3%82%AF%E3%83%AD%E3%82%B9%E9%9B%86%E8%A8%88%E3%81%8B%E3%82%89%E6%A9%9F%E6%A2%B0%E5%AD%A6%E7%BF%92%E3%81%BE%E3%81%A7%E3%81%AE%E3%83%93%E3%82%B8%E3%83%8D%E3%82%B9%E6%B4%BB%E7%94%A8%E4%BA%8B%E4%BE%8B&qid=1570003331&sr=8-1)
#     + 著者： 酒巻隆治, 里 洋平
#     + ISBN: 978-4489022012
#     + 初心者向け。ざっくり書いてある。自分で出来るようにはならないが、イメージはつかみやすい。ビジネスでの活用例が詳しい読み物。
#
# ## 原理から本格的に学ぶなら。。
# + 〇[統計的学習の基礎 : データマイニング・推論・予測](https://www.amazon.co.jp/%E7%B5%B1%E8%A8%88%E7%9A%84%E5%AD%A6%E7%BF%92%E3%81%AE%E5%9F%BA%E7%A4%8E-%E2%80%95%E3%83%87%E3%83%BC%E3%82%BF%E3%83%9E%E3%82%A4%E3%83%8B%E3%83%B3%E3%82%B0%E3%83%BB%E6%8E%A8%E8%AB%96%E3%83%BB%E4%BA%88%E6%B8%AC%E2%80%95-Trevor-Hastie/dp/432012362X/ref=sr_1_1?__mk_ja_JP=%E3%82%AB%E3%82%BF%E3%82%AB%E3%83%8A&keywords=%E7%B5%B1%E8%A8%88%E7%9A%84%E5%AD%A6%E7%BF%92%E3%81%AE%E5%9F%BA%E7%A4%8E&qid=1569984115&sr=8-1)
#     + 著者：Trevor Hastie, Robert Tibshirani, Jerome Friedman
#     + ISBN: 978-4320123625
#     + 分厚い。詳しい。全部読むのは大変そう。
# + 〇[多変量解析入門 : 線形から非線形へ](https://www.amazon.co.jp/%E5%A4%9A%E5%A4%89%E9%87%8F%E8%A7%A3%E6%9E%90%E5%85%A5%E9%96%80%E2%80%95%E2%80%95%E7%B7%9A%E5%BD%A2%E3%81%8B%E3%82%89%E9%9D%9E%E7%B7%9A%E5%BD%A2%E3%81%B8-%E5%B0%8F%E8%A5%BF-%E8%B2%9E%E5%89%87/dp/4000056530/ref=sr_1_1?__mk_ja_JP=%E3%82%AB%E3%82%BF%E3%82%AB%E3%83%8A&keywords=%E5%A4%9A%E5%A4%89%E9%87%8F%E8%A7%A3%E6%9E%90%E5%85%A5%E9%96%80+%3A+%E7%B7%9A%E5%BD%A2%E3%81%8B%E3%82%89%E9%9D%9E%E7%B7%9A%E5%BD%A2%E3%81%B8&qid=1569984048&sr=8-1)
#     + 著者：小西貞則
#     + ISBN: 978-4000056533
#     + 専門的。数学的には丁寧に書いてある。
# + 〇[深層学習 = Deep learning](https://www.amazon.co.jp/%E6%B7%B1%E5%B1%A4%E5%AD%A6%E7%BF%92-%E6%A9%9F%E6%A2%B0%E5%AD%A6%E7%BF%92%E3%83%97%E3%83%AD%E3%83%95%E3%82%A7%E3%83%83%E3%82%B7%E3%83%A7%E3%83%8A%E3%83%AB%E3%82%B7%E3%83%AA%E3%83%BC%E3%82%BA-%E5%B2%A1%E8%B0%B7-%E8%B2%B4%E4%B9%8B/dp/4061529021/ref=sr_1_2?__mk_ja_JP=%E3%82%AB%E3%82%BF%E3%82%AB%E3%83%8A&keywords=%E6%B7%B1%E5%B1%A4%E5%AD%A6%E7%BF%92&qid=1569984036&sr=8-2)
#     + 著者：岡谷貴之
#     + ISBN: 978-4061529021
#     + ディープラーニングのいろいろな手法が詳しく紹介されている。
# + 〇[データ分析とデータサイエンス](https://www.amazon.co.jp/%E3%83%87%E3%83%BC%E3%82%BF%E5%88%86%E6%9E%90%E3%81%A8%E3%83%87%E3%83%BC%E3%82%BF%E3%82%B5%E3%82%A4%E3%82%A8%E3%83%B3%E3%82%B9-%E6%9F%B4%E7%94%B0%E9%87%8C%E7%A8%8B/dp/4764904985/ref=sr_1_1?__mk_ja_JP=%E3%82%AB%E3%82%BF%E3%82%AB%E3%83%8A&keywords=%E3%83%87%E3%83%BC%E3%82%BF%E5%88%86%E6%9E%90%E3%81%A8%E3%83%87%E3%83%BC%E3%82%BF%E3%82%B5%E3%82%A4%E3%82%A8%E3%83%B3%E3%82%B9&qid=1569984210&sr=8-1)
#     + 著者：柴田里程
#     + ISBN: 978-4764904989
#     + 第8章　変量間の関係
#
# ## Python＆Jupyer 関連
# + [Pythonによるプログラミング入門　東京大学教養学部テキスト](https://www.amazon.co.jp/Python%E3%81%AB%E3%82%88%E3%82%8B%E3%83%97%E3%83%AD%E3%82%B0%E3%83%A9%E3%83%9F%E3%83%B3%E3%82%B0%E5%85%A5%E9%96%80-%E6%9D%B1%E4%BA%AC%E5%A4%A7%E5%AD%A6%E6%95%99%E9%A4%8A%E5%AD%A6%E9%83%A8%E3%83%86%E3%82%AD%E3%82%B9%E3%83%88-%E3%82%A2%E3%83%AB%E3%82%B4%E3%83%AA%E3%82%BA%E3%83%A0%E3%81%A8%E6%83%85%E5%A0%B1%E7%A7%91%E5%AD%A6%E3%81%AE%E5%9F%BA%E7%A4%8E%E3%82%92%E5%AD%A6%E3%81%B6-%E6%A3%AE%E7%95%91-%E6%98%8E%E6%98%8C/dp/413062458X/ref=sr_1_1?__mk_ja_JP=%E3%82%AB%E3%82%BF%E3%82%AB%E3%83%8A&keywords=Python%E3%81%AB%E3%82%88%E3%82%8B%E3%83%97%E3%83%AD%E3%82%B0%E3%83%A9%E3%83%9F%E3%83%B3%E3%82%B0%E5%85%A5%E9%96%80+%E6%9D%B1%E4%BA%AC%E5%A4%A7%E5%AD%A6%E6%95%99%E9%A4%8A%E5%AD%A6%E9%83%A8%E3%83%86%E3%82%AD%E3%82%B9%E3%83%88&qid=1569983310&sr=8-1)
#     + 著者：森畑 明昌
#     + ISBN: 978-4130624589
#     + Python入門
# + [PythonユーザのためのJupyter実践入門](https://www.amazon.co.jp/dp/4774192236/ref=sspa_dk_detail_5?psc=1&spLa=ZW5jcnlwdGVkUXVhbGlmaWVyPUFFUkFFMFhKSzBBMVMmZW5jcnlwdGVkSWQ9QTA5ODQyNzcyNjQ2ODNEVjA1SDA4JmVuY3J5cHRlZEFkSWQ9QTJPTFlKQjRUTzNNNkQmd2lkZ2V0TmFtZT1zcF9kZXRhaWwyJmFjdGlvbj1jbGlja1JlZGlyZWN0JmRvTm90TG9nQ2xpY2s9dHJ1ZQ==)
#     + 著者：池内 孝啓, 片柳 薫子, 岩尾 エマ はるか
#     + ISBN: 978-4774192239
#     + Jupyter入門。Pandas、Matplotlib、Bokeh(可視化ツール)が詳しい。
#
# ## 数値計算に興味があれば。。
# データ解析にはあまり関係ないかも。科学計算系。
# + 〇[Pythonによる数値計算とシミュレーション](https://www.amazon.co.jp/Python%E3%81%AB%E3%82%88%E3%82%8B%E6%95%B0%E5%80%A4%E8%A8%88%E7%AE%97%E3%81%A8%E3%82%B7%E3%83%9F%E3%83%A5%E3%83%AC%E3%83%BC%E3%82%B7%E3%83%A7%E3%83%B3-%E5%B0%8F%E9%AB%98-%E7%9F%A5%E5%AE%8F/dp/4274221709/ref=sr_1_1?__mk_ja_JP=%E3%82%AB%E3%82%BF%E3%82%AB%E3%83%8A&keywords=python+%E6%95%B0%E5%80%A4%E8%A8%88%E7%AE%97&qid=1569993683&sr=8-1)
#     + 著者：小高 知宏
#     + ISBN: 978-4274221705
#     + 数値計算用

# %% [markdown]
# # 便利なサイト　備忘録
#
# ## Python関係一般
# * **[Jupyter Notebook を使ってみよう](https://pythondatascience.plavox.info/python%E3%81%AE%E9%96%8B%E7%99%BA%E7%92%B0%E5%A2%83/jupyter-notebook%E3%82%92%E4%BD%BF%E3%81%A3%E3%81%A6%E3%81%BF%E3%82%88%E3%81%86):
# Python でデータサイエンス←例が豊富で分かりやすい。**
# * [Jupyter NoteBook を活用した Python3 プログラミング学習サイト](https://python.atelierkobato.com/):
# コードセルの基本操作は[こちら](https://python.atelierkobato.com/cell/)を参照
# * [データ分析で欠かせない！Jupyter Notebookの使い方【初心者向け】](https://techacademy.jp/magazine/17430)：
# Jupyter Notebookのインストール方法や使い方
# * [Python公式ドキュメント（日本語訳）](http://www.python.jp/):有志の方々によるPython公式ドキュメントの日本語訳を公開しているサイトです。
# * [PythonWeb](http://www.pythonweb.jp/):インストールや環境設定の方法と、Pythonの入門部分の学習ができます。
# * [Python-izm](https://www.python-izm.com/):Pythonの基礎～応用
# * [10分でPandasを学ぶ](https://qiita.com/tkazusa/items/23bc0142bf277d397260):Pandasの基礎
#
# その他、「Python　入門　おすすめ」などで検索すると、いろいろなサイトや入門書が出てきます。<br>
# 自分に合ったものを探してみてください。
#
# ## Python関係こまごまとしたこと
# * [Pythonらしいコードの書き方](http://kesin.hatenablog.com/entry/2013/05/12/004541)
# * [Windows 10でipynbファイルとJupyterノートブックを関連付ける（Anaconda）](https://codeday.me/jp/qa/20190401/519620.html)
#
# リストのコピーをするときは気を付けよう
# * [Python のリストの扱いで注意すること](https://qiita.com/utgwkk/items/5ad2527f19150ae33322)
# * [pythonでのリストの要素の変更とリストのコピー](https://qiita.com/masarin1126/items/a0afa4a5fecacdd02be9)
# * [わかっちゃいるけど、やめられない - Pythonあるある凡ミス集](https://qiita.com/tag1216/items/3db4d58b2f4e58c86103)
#
# ## Markdown記法
# Markdown記法も、検索すると色々出てきます。いいサイトがあれば、ぜひ紹介してください。
# * [Markdown記法](https://qiita.com/Blueman81/items/72ca43681d16d44e21ad)
# * [Markdown記法サンプル集](https://qiita.com/tbpgr/items/989c6badefff69377da7)
# * [新人のためのMarkdown記法まとめてみた](https://qiita.com/gctsubo/items/1e91f4913d845a0dd85a)
# * [ブログでよく使うMarkdownの書き方を忘れたときにみるもの。](http://final.hateblo.jp/category/Markdown#%E3%82%B3%E3%83%BC%E3%83%89)
